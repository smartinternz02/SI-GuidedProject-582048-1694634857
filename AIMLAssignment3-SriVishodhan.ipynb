# %% [markdown]
# SRI VISHODHAN

# %% [markdown]
# #TASK 1

# %% [markdown]
# DATA IS DOWNLOADED

# %% [markdown]
# #TASK 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/penguins_size.csv')
df
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %% [markdown]
# #TASK 3

# %% [markdown]
# ##UNIVARIATE ANALYSIS

# %%
df.species.value_counts()
# Out:
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: species, dtype: int64

# %%
plt.pie(df.species.value_counts(),[0,0,0],labels=df.species.unique(),autopct='%1.1f%%')
plt.show()

# %%
plt.pie(df.island.value_counts(),[0,0,0],labels=df.island.unique(),autopct='%1.1f%%')
plt.show()

# %%
df.sex.value_counts()
# Out:
# MALE      168
# FEMALE    165
# .           1
# Name: sex, dtype: int64

# %%
plt.pie(df.sex.value_counts(),autopct='%1.1f%%')
plt.show()

# %%
sns.distplot(df.culmen_length_mm)
# Out:
# <ipython-input-8-24e9b5890c61>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.culmen_length_mm)
# <Axes: xlabel='culmen_length_mm', ylabel='Density'>

# %%
sns.distplot(df.culmen_depth_mm)
# Out:
# <ipython-input-9-4b07ffb4fe44>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.culmen_depth_mm)
# <Axes: xlabel='culmen_depth_mm', ylabel='Density'>

# %%
sns.distplot(df.flipper_length_mm)
# Out:
# <ipython-input-10-4c42e92ff055>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.flipper_length_mm)
# <Axes: xlabel='flipper_length_mm', ylabel='Density'>

# %%
sns.distplot(df.body_mass_g)
# Out:
# <ipython-input-11-176964dae727>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.body_mass_g)
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %% [markdown]
# ##BI-VARIATE ANALYSIS

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen              39.1             18.7              181.0
# 1  Adelie  Torgersen              39.5             17.4              186.0
# 2  Adelie  Torgersen              40.3             18.0              195.0
# 3  Adelie  Torgersen               NaN              NaN                NaN
# 4  Adelie  Torgersen              36.7             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3          NaN     NaN
# 4       3450.0  FEMALE

# %%
sns.lineplot(x=df.body_mass_g, y=df.species)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='species'>

# %%
sns.lineplot(x=df.flipper_length_mm,y=df.species)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='species'>

# %%
sns.lineplot(x=df.culmen_length_mm,y=df.species)
# Out:
# <Axes: xlabel='culmen_length_mm', ylabel='species'>

# %%
sns.scatterplot(x=df.body_mass_g,y=df.species)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='species'>

# %%
sns.scatterplot(x=df.	flipper_length_mm,y=df.species)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='species'>

# %%
sns.scatterplot(x=df.culmen_depth_mm,y=df.species)
# Out:
# <Axes: xlabel='culmen_depth_mm', ylabel='species'>

# %% [markdown]
# ##MULTIVARIATE ANALYSIS

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-20-97cdbf7f1862>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# #TASK 4

# %%
df.describe()
# Out:
#        culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g
# count        342.000000       342.000000         342.000000   342.000000
# mean          43.921930        17.151170         200.915205  4201.754386
# std            5.459584         1.974793          14.061714   801.954536
# min           32.100000        13.100000         172.000000  2700.000000
# 25%           39.225000        15.600000         190.000000  3550.000000
# 50%           44.450000        17.300000         197.000000  4050.000000
# 75%           48.500000        18.700000         213.000000  4750.000000
# max           59.600000        21.500000         231.000000  6300.000000

# %% [markdown]
# #TASK 5

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# culmen_length_mm      2
# culmen_depth_mm       2
# flipper_length_mm     2
# body_mass_g           2
# sex                  10
# dtype: int64

# %% [markdown]
# FOR THE INT COLUMN WE WILL REPLACE THE NULL VALUE WITH THE MEDIAN
#
# FOR THE STRING COLUMN WILL USE MODE

# %%
df.culmen_length_mm = df.culmen_length_mm.fillna(df.culmen_length_mm.median())

# %%
df.culmen_depth_mm = df.culmen_depth_mm.fillna(df.culmen_depth_mm.median())

# %%
df.flipper_length_mm = df.flipper_length_mm.fillna(df.flipper_length_mm.median())

# %%
df.body_mass_g = df.body_mass_g.fillna(df.body_mass_g.median())

# %%
mode=df.sex.mode()
mode
# Out:
# 0    MALE
# Name: sex, dtype: object

# %%
df.sex = df.sex.fillna('MALE')

# %%
df.head()
# Out:
#   species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen             39.10             18.7              181.0
# 1  Adelie  Torgersen             39.50             17.4              186.0
# 2  Adelie  Torgersen             40.30             18.0              195.0
# 3  Adelie  Torgersen             44.45             17.3              197.0
# 4  Adelie  Torgersen             36.70             19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    MALE
# 1       3800.0  FEMALE
# 2       3250.0  FEMALE
# 3       4050.0    MALE
# 4       3450.0  FEMALE

# %%
df.isnull().sum()
# Out:
# species              0
# island               0
# culmen_length_mm     0
# culmen_depth_mm      0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# dtype: int64

# %% [markdown]
# #TASK 6

# %%
sns.boxplot(df.culmen_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.culmen_depth_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.flipper_length_mm)
# Out:
# <Axes: >

# %%
sns.boxplot(df.body_mass_g)
# Out:
# <Axes: >

# %% [markdown]
# THERE IS NO OUTLIER PRESENT

# %% [markdown]
# #TASK 7 and 8

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df.sex=le.fit_transform(df.sex)
df.island=le.fit_transform(df.island)
df.species=le.fit_transform(df.species)
#le.inverse_transform([9])

# %%
df.head()
# Out:
#   species  island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0  Adelie       2             39.10             18.7              181.0
# 1  Adelie       2             39.50             17.4              186.0
# 2  Adelie       2             40.30             18.0              195.0
# 3  Adelie       2             44.45             17.3              197.0
# 4  Adelie       2             36.70             19.3              193.0
#
#    body_mass_g  sex
# 0       3750.0    2
# 1       3800.0    1
# 2       3250.0    1
# 3       4050.0    2
# 4       3450.0    1

# %%
df.corr().species.sort_values(ascending=False)
# Out:
# species              1.000000
# flipper_length_mm    0.850819
# body_mass_g          0.747547
# culmen_length_mm     0.728706
# sex                 -0.003823
# island              -0.635659
# culmen_depth_mm     -0.741282
# Name: species, dtype: float64

# %% [markdown]
# #TASK 9

# %%
y=df.species
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 339    2
# 340    2
# 341    2
# 342    2
# 343    2
# Name: species, Length: 344, dtype: int64

# %%
x=df.drop(columns=['species'],axis=1)
x.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0       2             39.10             18.7              181.0       3750.0
# 1       2             39.50             17.4              186.0       3800.0
# 2       2             40.30             18.0              195.0       3250.0
# 3       2             44.45             17.3              197.0       4050.0
# 4       2             36.70             19.3              193.0       3450.0
#
#    sex
# 0    2
# 1    1
# 2    1
# 3    2
# 4    1

# %% [markdown]
# #TASK 10

# %%
from sklearn.preprocessing import MinMaxScaler
scale=MinMaxScaler()

# %%
X_scaled=pd.DataFrame(scale.fit_transform(x),columns=x.columns)
X_scaled.head()
# Out:
#    island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  body_mass_g  \
# 0     1.0          0.254545         0.666667           0.152542     0.291667
# 1     1.0          0.269091         0.511905           0.237288     0.305556
# 2     1.0          0.298182         0.583333           0.389831     0.152778
# 3     1.0          0.449091         0.500000           0.423729     0.375000
# 4     1.0          0.167273         0.738095           0.355932     0.208333
#
#    sex
# 0  1.0
# 1  0.5
# 2  0.5
# 3  1.0
# 4  0.5

# %% [markdown]
# #TASK 11

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_scaled,y,test_size=0.3,random_state=0) #y=target data

# %% [markdown]
# #TASK 12

# %%
X_train.shape
# Out:
# (240, 6)

# %%
X_test.shape
# Out:
# (104, 6)

# %%
y_train.shape
# Out:
# (240,)

# %%
y_test.shape
# Out:
# (104,)
